# %% [markdown]
# <a href="https://colab.research.google.com/github/ydchen17/PPI_Analysis_Project/blob/main/correlation_check.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
data <- read.csv("/content/4.4SCR_weired.csv")

# %%
head(data)
colnames(data)
# Out:
#   X y_protein SCR   centrality neighbors_num_all neighbors_num_conserved
# 1 0 YPR183W   71.91 0.000407    2                 0
# 2 1 YGL237C   73.58 0.001221   10                 4
# 3 2 YEL016C   79.51 0.000203    2                 1
# 4 3 YDL059C   77.73 0.000407    2                 1
# 5 4 YJR110W   72.38 0.002238   12                 7
# 6 5 YEL063C   84.41 0.008950   44                11
#   neighbors_num_specific h_protein       h_neighbors_num_all
# 1  2                     ENSP00000360644 9
# 2  6                     ENSP00000345702 1
# 3  1                     ENSP00000318066 0
# 4  1                     ENSP00000351284 3
# 5  5                     ENSP00000371221 7
# 6 33                     ENSP00000501493 0
#   h_neighbors_num_conserved h_neighbors_num_specific Neighbour_Change_Rate
# 1 0                         9                        350.00
# 2 0                         1                         90.00
# 3 0                         0                        100.00
# ...

# %%
install.packages('psych')
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘tmvnsim’, ‘mnormt’

# %%
df = data[-c(1,2,8,15,16)]
# Out:
#      SCR   centrality neighbors_num_all neighbors_num_conserved
# 1    71.91 0.000407     2                0
# 2    73.58 0.001221    10                4
# 3    79.51 0.000203     2                1
# 4    77.73 0.000407     2                1
# 5    72.38 0.002238    12                7
# 6    84.41 0.008950    44               11
# 7    87.52 0.003051    16                3
# 8    43.69 0.000407     3                2
# 9    66.67 0.001017     5                2
# 10   76.00 0.000814     7                0
# 11   79.43 0.000203     3                1
# 12   80.58 0.000203     1                1
# 13   73.35 0.000203     1                0
# 14   69.26 0.001831    14                5
# 15   49.74 0.001831     9                3
# 16   66.12 0.001627    24                3
# 17   92.15 0.002644    24                7
# 18   77.59 0.000610     9                2
# 19   67.72 0.001831    23                6
# 20   79.55 0.003662   125                6
# ...

# %%
fm = lm(SCR~.,data = df)

# %%
lm(SCR~.,data = df)

system("wget http://txcdn.ydchen.cn/entrez.zip") 
unzip("entrez.zip") 
human_all <- scan("entrez/human_all_entrez.txt", sep="\n") 
human_conserved <- scan("entrez/human_conserved_entrez.txt", sep="\n") 
human_specific <- scan("entrez/human_specific_entrez.txt", sep="\n") 
yeast_all <- scan("entrez/yeast_all_entrez.txt", what="", sep="\n") 
yeast_conserved <- scan("entrez/yeast_conserved_entrez.txt", sep="\n") 
yeast_specific <- scan("entrez/yeast_specific_entrez.txt", sep="\n")
# Out:
# Error in parse(text = x, srcfile = src): <text>:6:59: unexpected string constant
# 5: human_all <- scan("entrez/human_all_entrez.txt", sep="\n")
# 6: human_conserved <- scan(entrez/ human_conserved_entrez.txt", sep="
#                                                              ^
# Traceback:

# %%
summary(fm)
# Out:
# Call:
# lm(formula = SCR ~ ., data = df)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -54.412  -8.060   2.924  10.590  52.542
#
# Coefficients: (2 not defined because of singularities)
#                                   Estimate Std. Error t value Pr(>|t|)
# (Intercept)                      7.190e+01  5.650e-01 127.264  < 2e-16 ***
# centrality                       2.361e+03  3.818e+02   6.184 7.77e-10 ***
# neighbors_num_all               -2.442e-02  1.046e-02  -2.336  0.01960 *
# neighbors_num_conserved         -1.044e+00  1.606e-01  -6.498 1.06e-10 ***
# neighbors_num_specific                  NA         NA      NA       NA
# h_neighbors_num_all             -2.131e-01  3.855e-02  -5.529 3.73e-08 ***
# h_neighbors_num_conserved        7.222e-01  1.581e-01   4.568 5.28e-06 ***
# h_neighbors_num_specific                NA         NA      NA       NA
# Neighbour_Change_Rate           -8.087e-03  1.359e-03  -5.952 3.21e-09 ***
# ...

# %%
plot(fm)
# Out:
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”

# %%
fm = lm(SCR~centrality+neighbors_num_all+neighbors_num_conserved+neighbors_num_specific,data = df)

# %%
summary(fm)
# Out:
# Call:
# lm(formula = SCR ~ centrality + neighbors_num_all + neighbors_num_conserved +
#     neighbors_num_specific, data = df)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -55.803  -7.680   3.495  10.867  39.679
#
# Coefficients: (1 not defined because of singularities)
#                           Estimate Std. Error t value Pr(>|t|)
# (Intercept)               70.03708    0.43026 162.778  < 2e-16 ***
# centrality              2161.99700  384.23100   5.627 2.14e-08 ***
# neighbors_num_all         -0.02634    0.01057  -2.493   0.0128 *
# neighbors_num_conserved   -0.96107    0.16234  -5.920 3.87e-09 ***
# neighbors_num_specific          NA         NA      NA       NA
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 15.07 on 1719 degrees of freedom
# Multiple R-squared:  0.03435,	Adjusted R-squared:  0.03266
# F-statistic: 20.38 on 3 and 1719 DF,  p-value: 5.607e-13

# %%
plot(fm)
# Out:
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”

# %%
fm = glm(SCR~centrality+neighbors_num_all+neighbors_num_conserved+neighbors_num_specific,data = df, family = Gamma)

# %%
summary(fm)
# Out:
# Call:
# glm(formula = SCR ~ centrality + neighbors_num_all + neighbors_num_conserved +
#     neighbors_num_specific, family = Gamma, data = df)
#
# Deviance Residuals:
#      Min        1Q    Median        3Q       Max
# -1.39144  -0.11565   0.04815   0.14952   0.62895
#
# Coefficients: (1 not defined because of singularities)
#                           Estimate Std. Error t value Pr(>|t|)
# (Intercept)              1.425e-02  9.244e-05 154.212  < 2e-16 ***
# centrality              -4.642e-01  8.004e-02  -5.800 7.88e-09 ***
# neighbors_num_all        6.237e-06  2.572e-06   2.425   0.0154 *
# neighbors_num_conserved  2.128e-04  3.519e-05   6.048 1.80e-09 ***
# neighbors_num_specific          NA         NA      NA       NA
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Gamma family taken to be 0.0481063)
#
#     Null deviance: 107.20  on 1722  degrees of freedom
# Residual deviance: 104.09  on 1719  degrees of freedom
# ...

# %%
plot(fm)
# Out:
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”

# %%
 help(family)
# Out:
# Warning message in seq_len(head.end.idx):
# “first element used of 'length.out' argument”
# ERROR while rich displaying an object: Error in seq_len(head.end.idx): argument must be coercible to non-negative integer
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
# ...

# %%
fm = glm(SCR~centrality+neighbors_num_all+neighbors_num_conserved+neighbors_num_specific,data = df, family = gaussian())

# %%
summary(fm)
# Out:
# Call:
# glm(formula = SCR ~ centrality + neighbors_num_all + neighbors_num_conserved +
#     neighbors_num_specific, family = gaussian(), data = df)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -55.803   -7.680    3.495   10.867   39.679
#
# Coefficients: (1 not defined because of singularities)
#                           Estimate Std. Error t value Pr(>|t|)
# (Intercept)               70.03708    0.43026 162.778  < 2e-16 ***
# centrality              2161.99700  384.23100   5.627 2.14e-08 ***
# neighbors_num_all         -0.02634    0.01057  -2.493   0.0128 *
# neighbors_num_conserved   -0.96107    0.16234  -5.920 3.87e-09 ***
# neighbors_num_specific          NA         NA      NA       NA
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for gaussian family taken to be 227.0965)
#
#     Null deviance: 404264  on 1722  degrees of freedom
# Residual deviance: 390379  on 1719  degrees of freedom
# AIC: 14244
#
# ...

# %%
plot(fm)
# Out:
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”

# %%
fm = glm(SCR~centrality+neighbors_num_all+neighbors_num_conserved+neighbors_num_specific,data = df, family = poisson())
# Out:
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 71.910000”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 73.580000”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 79.510000”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 77.730000”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 72.380000”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 84.410000”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 87.520000”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 43.690000”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 66.670000”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 79.430000”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 80.580000”
# Warning message in dpois(y, mu, log = TRUE):
# “non-integer x = 73.350000”
# Warning message in dpois(y, mu, log = TRUE):
# ...

# %%
summary(fm)
# Out:
# Call:
# glm(formula = SCR ~ centrality + neighbors_num_all + neighbors_num_conserved +
#     neighbors_num_specific, family = poisson(), data = df)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -8.4680  -0.9406   0.4046   1.2727   5.0212
#
# Coefficients: (1 not defined because of singularities)
#                           Estimate Std. Error  z value Pr(>|z|)
# (Intercept)              4.250e+00  3.477e-03 1222.347  < 2e-16 ***
# centrality               3.172e+01  3.060e+00   10.366  < 2e-16 ***
# neighbors_num_all       -4.046e-04  9.105e-05   -4.444 8.84e-06 ***
# neighbors_num_conserved -1.433e-02  1.318e-03  -10.875  < 2e-16 ***
# neighbors_num_specific          NA         NA       NA       NA
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for poisson family taken to be 1)
#
#     Null deviance: 6444.9  on 1722  degrees of freedom
# Residual deviance: 6237.0  on 1719  degrees of freedom
# AIC: Inf
#
# ...
